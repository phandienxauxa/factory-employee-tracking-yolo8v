# %%
# !nvidia-smi
# Out:
# Sat Jul  4 07:54:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics roboflow -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.5 MB/s eta 0:00:00

# %%
import os

for root, dirs, files in os.walk("/content"):
  for file in files:
    if file == "data.yaml":
      print(os.path.join(root, file))
# Out:
# /content/demo1-2/data.yaml

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.2 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

DATA_YAML = "/content/demo1-2/data.yaml"

model = YOLO("yolov8n.pt")

model.train(
    data=DATA_YAML,
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    workers=2,
    project="/content/runs",
    name="person_factory_yolov8n"
)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EoISIJloIsLrlmNYZ92M")
project = rf.workspace("mus-workspace-wns5n").project("demo1-sj1he")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 85.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 138.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to demo1-2 in yolov8:: 100%|██████████| 229/229 [00:00<00:00, 6558.97it/s]

# %%
from google.colab import files

files.download("/content/runs/person_factory_yolov8n-2/weights/best.pt")

# %% [markdown]
# // Export Dataset từ Roboflow sang OpenVino

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/person_factory_yolov8n-2/weights/best.pt")

model.export(
    format = "openvino",
    imgsz = 640
)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/runs/person_factory_yolov8n-2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 3 packages in 390ms
# Prepared 2 packages in 1.63s
# Installed 2 packages in 29ms
#  + openvino==2026.2.1
#  + openvino-telemetry==2025.2.0
#
# requirements: AutoUpdate success ✅ 2.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2026.2.1-21919-ede283a88e3-releases/2026/2...
# ...

# %%
# !zip -r best_openvino_model.zip /content/runs/person_factory_yolov8n-2/weights/best_openvino_model
# Out:
#   adding: content/runs/person_factory_yolov8n-2/weights/best_openvino_model/ (stored 0%)
#   adding: content/runs/person_factory_yolov8n-2/weights/best_openvino_model/best.xml (deflated 94%)
#   adding: content/runs/person_factory_yolov8n-2/weights/best_openvino_model/metadata.yaml (deflated 37%)
#   adding: content/runs/person_factory_yolov8n-2/weights/best_openvino_model/best.bin (deflated 13%)

# %%
from google.colab import files

files.download("best_openvino_model.zip")
